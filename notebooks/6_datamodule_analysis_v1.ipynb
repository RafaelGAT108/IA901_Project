# %%
import os
import sys
# Add the parent directory to the Python path to allow module imports
sys.path.append(os.path.dirname(os.getcwd()))

# Set random seed for reproducibility
SEED = 42
import random
random.seed(SEED)
import torch
torch.manual_seed(SEED)

import librosa
from matplotlib import pyplot as plt
from pprint import pprint

from modules.datamodule import LungSoundDataModule
from modules.transforms import *

# NOTE: Some classes have very few samples, so we will focus on a subset of classes for the analysis.
SELECTED_CLASSES = [
    "Asthma",
    "Bronchiectasis",
    "Bronchiolitis",
    "COPD",
    "Healthy",
    "Lung Fibrosis",
    "Pneumonia",
    "URTI",
]

TARGET_SR = 22050   # Hz
WINDOW_LENGTH = 6   # seconds
HOP_LENGTH = 6      # seconds
  
config = {
    "dataset": {
        "name": "Combined_ICBHI_KAUH",
        "classes": SELECTED_CLASSES,
        "feature_format": "npy",
        "feature_extractor": "STFT",
        "num_channels": 1,
    },
    "batch_size": 16,
    "num_workers": 4,
    "sampler": None,
    "seed": SEED,
}

# %%
DATA_FOLDER = os.path.join(os.path.dirname(os.getcwd()), "data/preprocessed")
if not os.path.exists(DATA_FOLDER):
    print(f"Data directory not found at {DATA_FOLDER}. Please ensure the data is downloaded and placed in the correct location.")

# %%
config = {
    "dataset": {
        "name": "Combined_ICBHI_KAUH",
        "classes": SELECTED_CLASSES,
        "feature_format": "npy",
        "feature_extractor": "STFT",
        "num_channels": 1,
    },
    "batch_size": 16,
    "num_workers": 4,
    "sampler": None,
    "seed": SEED,
}

def visualize_npy_batch(datamodule: LungSoundDataModule, class_names: list):
    """ Visualize a batch of samples from the dataloader. """
    labels_counter = {class_name: 0 for class_name in class_names}
    dataloader = datamodule.train_dataloader()
    batch_samples, batch_labels = next(iter(dataloader))
    num_rows = len(batch_samples) // 4
    num_cols = len(batch_samples) // num_rows
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(4 * num_cols, 3 * num_rows))
    axes = axes.flatten()
    for i in range(len(batch_samples)):
        sample = batch_samples[i]
        label = batch_labels[i]
        class_name = class_names[label.item()]
        np_sample = sample.cpu().numpy().squeeze()
        params = datamodule.train_dataset.get_plot_params()
        if np_sample.ndim == 2:  # If the sample is a 2D array (e.g., spectrogram)
            librosa.display.specshow(np_sample, sr=TARGET_SR, ax=axes[i], **params)
        else:  # If the sample is a 3D array (e.g., RGB image)
            np_sample = np_sample.transpose(1, 2, 0)  # Convert from (C, H, W) to (H, W, C)
            axes[i].imshow(np_sample)
        axes[i].set_title(f"{class_name} (Label: {label.item()})")
        labels_counter[class_name] += 1
    pprint(labels_counter)
    plt.tight_layout()
    plt.show()

# %%
dm = LungSoundDataModule(config, DATA_FOLDER)
dm.setup()
visualize_npy_batch(dm, SELECTED_CLASSES)
# Out:
# {'Asthma': 1,
#  'Bronchiectasis': 1,
#  'Bronchiolitis': 0,
#  'COPD': 11,
#  'Healthy': 3,
#  'Lung Fibrosis': 0,
#  'Pneumonia': 0,
#  'URTI': 0}

# %%
config["sampler"] = "equalizer"
dm = LungSoundDataModule(config, DATA_FOLDER)
dm.setup()
visualize_npy_batch(dm, SELECTED_CLASSES)
# Out:
# {'Asthma': 1,
#  'Bronchiectasis': 0,
#  'Bronchiolitis': 1,
#  'COPD': 1,
#  'Healthy': 4,
#  'Lung Fibrosis': 3,
#  'Pneumonia': 5,
#  'URTI': 1}

# %%
config["dataset"]["feature_format"] = "png"

def visualize_png_batch(datamodule: LungSoundDataModule, class_names: list):
    """ Visualize a batch of samples from the dataloader. """
    labels_counter = {class_name: 0 for class_name in class_names}
    dataloader = datamodule.train_dataloader()
    batch_samples, batch_labels = next(iter(dataloader))
    num_rows = len(batch_samples) // 4
    num_cols = len(batch_samples) // num_rows
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(4 * num_cols, 3 * num_rows))
    axes = axes.flatten()
    for i in range(len(batch_samples)):
        sample = batch_samples[i]
        label = batch_labels[i]
        class_name = class_names[label.item()]
        np_sample = sample.cpu().numpy().squeeze().transpose(1, 2, 0)
        axes[i].imshow(np_sample)
        axes[i].set_title(f"{class_name} (Label: {label.item()})")
        labels_counter[class_name] += 1
    pprint(labels_counter)
    plt.tight_layout()
    plt.show()

# %%
dm = LungSoundDataModule(config, DATA_FOLDER)
dm.setup()
visualize_png_batch(dm, SELECTED_CLASSES)
# Out:
# {'Asthma': 1,
#  'Bronchiectasis': 1,
#  'Bronchiolitis': 2,
#  'COPD': 0,
#  'Healthy': 0,
#  'Lung Fibrosis': 6,
#  'Pneumonia': 5,
#  'URTI': 1}

# %%
config["dataset"]["feature_format"] = "npy"
config["dataset"]["feature_extractor"] = "Stack_MelSpectrogram_MFCC_Chroma"
dm = LungSoundDataModule(config, DATA_FOLDER)
dm.setup()
visualize_npy_batch(dm, SELECTED_CLASSES)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-469.49088..170.07384].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-280.30527..140.26431].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-481.34308..197.31403].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-457.74878..118.91031].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-389.05035..177.69043].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-464.4015..117.84348].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-425.5197..248.5704].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-475.00537..185.29474].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-288.07547..139.74716].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-443.07498..167.65082].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-457.74878..118.91031].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-469.44534..153.88846].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-443.2563..222.22392].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-480.81412..149.87732].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-378.33127..185.31946].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-331.8141..129.59328].
# {'Asthma': 2,
#  'Bronchiectasis': 1,
#  'Bronchiolitis': 2,
#  'COPD': 5,
#  'Healthy': 1,
#  'Lung Fibrosis': 1,
#  'Pneumonia': 1,
#  'URTI': 3}
